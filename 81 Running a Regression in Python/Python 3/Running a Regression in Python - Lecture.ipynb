# %%
import numpy as np
import pandas as pd

from scipy import stats
import statsmodels.api as sm  # a suffix indicating we will import a large part of the stance models

import matplotlib.pyplot as plt

# %%
data = pd.read_excel('C:/Users/USER/Documents/Udemy Python for Finance/81 Running a Regression in Python/Python 3/Housing.xlsx')

# %%
data
# Out:
#     House Price  House Size (sq.ft.) State  Number of Rooms  \
# 0       1116000                 1940    IN                8
# 1        860000                 1300    IN                5
# 2        818400                 1420    IN                6
# 3       1000000                 1680    IN                7
# 4        640000                 1270    IN                5
# 5       1010000                 1850    IN                7
# 6        600000                 1000    IN                4
# 7        700000                 1100   LA                 4
# 8       1100000                 1600   LA                 7
# 9        570000                 1000    NY                5
# 10       860000                 2150    NY                9
# 11      1085000                 1900    NY                9
# 12      1250000                 2200    NY                9
# 13       850000                 1100    TX                4
# 14       640000                  860    TX                4
# ...

# %%
data[['House Price', 'House Size (sq.ft.)']]
# Out:
#     House Price  House Size (sq.ft.)
# 0       1116000                 1940
# 1        860000                 1300
# 2        818400                 1420
# 3       1000000                 1680
# 4        640000                 1270
# 5       1010000                 1850
# 6        600000                 1000
# 7        700000                 1100
# 8       1100000                 1600
# 9        570000                 1000
# 10       860000                 2150
# 11      1085000                 1900
# 12      1250000                 2200
# 13       850000                 1100
# 14       640000                  860
# 15       900000                 1325
# 16       730000                 1350
# 17       750000                 1600
# 18       650000                  950
# 19       680000                 1250

# %% [markdown]
# ### Univariate Regression

# %%
X = data['House Size (sq.ft.)']
Y = data['House Price']

# %%
X
# Out:
# 0     1940
# 1     1300
# 2     1420
# 3     1680
# 4     1270
# 5     1850
# 6     1000
# 7     1100
# 8     1600
# 9     1000
# 10    2150
# 11    1900
# 12    2200
# 13    1100
# 14     860
# 15    1325
# 16    1350
# 17    1600
# 18     950
# 19    1250
# Name: House Size (sq.ft.), dtype: int64

# %%
Y
# Out:
# 0     1116000
# 1      860000
# 2      818400
# 3     1000000
# 4      640000
# 5     1010000
# 6      600000
# 7      700000
# 8     1100000
# 9      570000
# 10     860000
# 11    1085000
# 12    1250000
# 13     850000
# 14     640000
# 15     900000
# 16     730000
# 17     750000
# 18     650000
# 19     680000
# Name: House Price, dtype: int64

# %%
plt.scatter(X,Y)
plt.show()

# %%
plt.scatter(X,Y)
plt.axis([0, 2500, 0, 1500000]) # adjust the graph's 2 axis
plt.show()

# %%
plt.scatter(X,Y)
plt.axis([0, 2500, 0, 1500000])
plt.ylabel('House Price')
plt.xlabel('House Size (sq.ft)')
plt.show()
